# %%
import pandas as pd
df = pd.read_csv('/content/Book1.1.csv')
df.head(100)
# Out:
#     rotation speed  Tool wear
# 0             1412        140
# 1             2861        143
# 2             1383        145
# 3             1497        147
# 4             1565        152
# ..             ...        ...
# 95            1391        169
# 96            1513        172
# 97            1612        174
# 98            1515        179
# 99            1379        181
#
# [100 rows x 2 columns]

# %%
duplicates = df[df['rotation speed'].duplicated()]
duplicatefailure= df[df['Tool wear'].duplicated()]
print(duplicates)
print(duplicatefailure)
# Out:
#     rotation speed  Tool wear
# 24            1592        200
# 44            1450         40
# 50            1523         55
# 55            1450         66
# 57            1445         70
# 58            1497         72
# 75            1727        116
# 83            1441        132
# 85            1369        138
# 92            1544        159
# 96            1513        172
# 99            1379        181
#     rotation speed  Tool wear
# 86            1711        140
# 87            1420        143
# 95            1391        169
# 96            1513        172
# 97            1612        174
# 98            1515        179
# 99            1379        181

# %%
df =df.drop_duplicates()
df_cleaned = df.drop_duplicates()
print(df_cleaned)
# Out:
#     rotation speed  Tool wear
# 0             1412        140
# 1             2861        143
# 2             1383        145
# 3             1497        147
# 4             1565        152
# ..             ...        ...
# 95            1391        169
# 96            1513        172
# 97            1612        174
# 98            1515        179
# 99            1379        181
#
# [100 rows x 2 columns]

# %%
unique_values = df.value_counts()
print(unique_values)
df.head(200)
# Out:
# rotation speed  Tool wear
# 1268            155          1
# 1558            110          1
# 1592            200          1
#                 169          1
# 1591            68           1
#                             ..
# 1445            70           1
#                 4            1
# 1441            132          1
#                 63           1
# 2861            143          1
# Length: 100, dtype: int64
#     rotation speed  Tool wear
# 0             1412        140
# 1             2861        143
# 2             1383        145
# 3             1497        147
# 4             1565        152
# ..             ...        ...
# 95            1391        169
# 96            1513        172
# 97            1612        174
# 98            1515        179
# 99            1379        181
#
# [100 rows x 2 columns]

# %%
null = df.isnull().sum()
print(null)
# Out:
# rotation speed    0
# Tool wear         0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
X=df[['Tool wear']]
y = df[['rotation speed']]
#y = condition[['Process temperature [K]']]
regressor = LinearRegression()
regressor.fit(X,y)
df.plot(x='Tool wear',y='rotation speed',style='.')
#condition.plot(x='Tool wear [min]',y='Process temperature [K]',style='.')
plt.plot(X, regressor.predict(X), color='purple', label='Regression line')
plt.xlabel('Tool wear')
plt.ylabel('rotation speed')
#plt.ylabel('Process temperature [K]')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = pd.DataFrame(df['Tool wear'])
y = pd.DataFrame(df['rotation speed'])
#y = pd.DataFrame(condition['Process temperature [K]'])
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=1)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80, 1)
# (20, 1)
# (80, 1)
# (20, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
print("Intercept is: ",regressor.intercept_)
print("Slope is: ",regressor.coef_)
# Out:
# Intercept is:  [1543.67011201]
# Slope is:  [[-0.06201595]]

# %%
y_pred = regressor.predict(x_test)
print(y_pred)
y_test.head(10)
# Out:
# [[1535.85610189]
#  [1535.29795831]
#  [1542.98793652]
#  [1535.73206998]
#  [1533.68554352]
#  [1532.44522445]
#  [1542.6158408 ]
#  [1535.60803807]
#  [1537.28246881]
#  [1537.77859644]
#  [1533.80957543]
#  [1541.99568127]
#  [1539.45302718]
#  [1540.01117076]
#  [1540.13520267]
#  [1543.11196843]
#  [1543.42204819]
#  [1541.18947387]
#  [1536.1041657 ]
#  [1533.43747971]]
#     rotation speed
# 80            1559
# 84            1430
# 33            1453
# 81            1473
# 93            1778
# 17            1679
# 36            1804
# 82            1737
# 69            1707
# 65            1680

# %%
from sklearn import metrics
import numpy as np
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("Mean Absolute Error", mae)
print("Mean Squared Error", mse)
print("Root Mean Squared Error", rmse)
# Out:
# Mean Absolute Error 147.7798995977061
# Mean Squared Error 32363.14095269353
# Root Mean Squared Error 179.89758462162166

# %%
import joblib
import pickle
#train my linear regression model
model = LinearRegression()
model.fit(x,y)
#save the trained model to a file using joblib
joblib.dump(model, '.pkl')
# Or Save the model using pickle
with open('MANUFACTURING EQUIPMENT.pkl', 'wb') as file:
  pickle.dump(model, file)

# %%
new_x = np.array([10,20,30,40,50]).reshape(-1,1)
model = joblib.load('MANUFACTURING EQUIPMENT.pkl')
predictions = model.predict(new_x)
new_data=pd.DataFrame({'x':new_x.flatten(), 'Predicted_y': predictions.flatten()})
print(new_data)
# Out:
#     x  Predicted_y
# 0  10  1557.932238
# 1  20  1556.910357
# 2  30  1555.888476
# 3  40  1554.866594
# 4  50  1553.844713
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
